# %%
import pandas as pd
import requests

# %%
emails = pd.read_csv('/Users/adambachrach/Desktop/Email_Validation/invalid_emails.csv')
emails_df = pd.DataFrame(emails)
emails_df
# Out:
#           ID                            Email   status     Unnamed: 3  \
# 0     134765                danielbara@37.com  invalid     danielbara
# 1     173210             jsoden@111eighth.com  invalid         jsoden
# 2     409364               larry@200e62ny.com  invalid          larry
# 3     206155  dennis.sherry@245parkavenyc.com  invalid  dennis.sherry
# 4     214153          jgoldberg@2iprtners.com  invalid      jgoldberg
# ...      ...                              ...      ...            ...
# 1343   50000            lgrunwald@ytypupa.org  invalid      lgrunwald
# 1344  411524                 rsalpeter@yu.edu  invalid      rsalpeter
# 1345  416081    joseph.benari@einstein.yu.edu  invalid  joseph.benari
# 1346  480001                sklien@zalmen.com  invalid         sklien
# 1347  167598      jgeraci@zenithterminals.com  invalid        jgeraci
#
#                         New Email           Unnamed: 5 Unnamed: 6  \
# ...

# %%
just_emails = emails_df['Email']
just_emails
# Out:
# 0                     danielbara@37.com
# 1                  jsoden@111eighth.com
# 2                    larry@200e62ny.com
# 3       dennis.sherry@245parkavenyc.com
# 4               jgoldberg@2iprtners.com
#                      ...
# 1343              lgrunwald@ytypupa.org
# 1344                   rsalpeter@yu.edu
# 1345      joseph.benari@einstein.yu.edu
# 1346                  sklien@zalmen.com
# 1347        jgeraci@zenithterminals.com
# Name: Email, Length: 1348, dtype: object
